# %%
# !pip install --upgrade gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Collecting gensim
#   Downloading gensim-4.1.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.1 MB)
#      |████████████████████████████████| 24.1 MB 42.1 MB/s
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.19.5)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.2.1)
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-4.1.2

# %%
import os
import tensorflow as tf
import keras
import keras.applications.vgg16
from keras.utils import np_utils
import numpy as np
import matplotlib.pyplot as plt
import string
from pickle import load, dump
from nltk.translate.bleu_score import corpus_bleu
import gensim

from google.colab import drive
drive.mount('/content/drive')

tf.test.gpu_device_name()
# Out:
# Mounted at /content/drive
# '/device:GPU:0'

# %%
def feature_extractions(directory):
    """
    Input: directory of images
    Return: A dictionary of features extracted by VGG-16, size 4096.
    """
    
    model = keras.applications.vgg16.VGG16()
    model = keras.models.Model(inputs=model.input, outputs=model.layers[-2].output) #Remove the final layer
    
    features = {}
    for f in os.listdir(directory):
        filename = directory + "/" + f
        identifier = f.split('.')[0]
        
        image = keras.preprocessing.image.load_img(filename, target_size=(224,224))
        arr = keras.preprocessing.image.img_to_array(image, dtype=np.float32)
        arr = arr.reshape((1, arr.shape[0], arr.shape[1], arr.shape[2]))
        arr = keras.applications.vgg16.preprocess_input(arr)
    
        feature = model.predict(arr, verbose=0)
        features[identifier] = feature
        
        print("feature extraction: {}".format(f))
    return(features)

features = feature_extractions("/content/drive/My Drive/Flickr8k_Dataset")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# feature extraction: 3138433655_ea1d59e5b7.jpg
# feature extraction: 3133403457_95dfe11da1.jpg
# feature extraction: 3116039960_54d1d68145.jpg
# feature extraction: 3154886184_ac842655b6.jpg
# feature extraction: 3148193539_de9dd48fc8.jpg
# feature extraction: 3162289423_4ca8915d0c.jpg
# feature extraction: 3112635165_2d614d7c1a.jpg
# feature extraction: 3151365121_e2a685a666.jpg
# feature extraction: 3171651115_e07b9d08f6.jpg
# feature extraction: 3155400369_69e3d6d70f.jpg
# feature extraction: 3118534315_cc03e5ddab.jpg
# feature extraction: 3138504165_c7ae396294.jpg
# feature extraction: 3109136206_f7d201b368.jpg
# feature extraction: 3131990048_369b081021.jpg
# feature extraction: 3150252702_828a570d46.jpg
# feature extraction: 3169394115_2193158cee.jpg
# feature extraction: 311146855_0b65fdb169.jpg
# feature extraction: 3125628091_25a31709df.jpg
# feature extraction: 3123463486_f5b36a3624.jpg
# feature extraction: 3125309108_1011486589.jpg
# feature extraction: 3123526484_02952e40fc.jpg
# feature extraction: 3163323414_d1ce127aa6.jpg
# feature extraction: 3145967309_b33abe4d84.jpg
# feature extraction: 3170856184_efabfd0297.jpg
# feature extraction: 3143991972_7193381aeb.jpg
# feature extraction: 3141613533_595723208d.jpg
# feature extraction: 3159092624_66af4e207e.jpg
# feature extraction: 3141293960_74459f0a24.jpg
# feature extraction: 3139895886_5a6d495b13.jpg
# feature extraction: 3122579598_14841c038a.jpg
# feature extraction: 3168354472_866fe70d36.jpg
# feature extraction: 3113322995_13781860f2.jpg
# feature extraction: 3106791484_13e18c33d8.jpg
# feature extraction: 3163068926_d28ed3ef53.jpg
# feature extraction: 3109268897_d43797fc6a.jpg
# feature extraction: 3172369593_eb4d787ffb.jpg
# feature extraction: 3119696225_b289efaec8.jpg
# feature extraction: 3126752627_dc2d6674da.jpg
# feature extraction: 3155361712_2cbf59c78e.jpg
# feature extraction: 3111897772_5211a37a02.jpg
# feature extraction: 3148286846_40ae914172.jpg
# feature extraction: 3159447439_c1496cbaea.jpg
# feature extraction: 3111482098_11c0f4f309.jpg
# feature extraction: 3126795109_73920ed5dc.jpg
# feature extraction: 3169591322_d0b6d0cd04.jpg
# feature extraction: 3118505332_b0792489b5.jpg
# feature extraction: 3143155555_32b6d24f34.jpg
# feature extraction: 3171066023_ec60ba30f3.jpg
# feature extraction: 3117562746_62f57a02b5.jpg
# feature extraction: 313326614_b2adbe59e0.jpg
# feature extraction: 3143765063_a7761b16d3.jpg
# feature extraction: 3122888809_9ae9b4b9b2.jpg
# feature extraction: 3147913471_322ea231d9.jpg
# feature extraction: 314685044_da4390728e.jpg
# feature extraction: 3173157541_70b16b4318.jpg
# feature extraction: 3157744152_31ace8c9ed.jpg
# feature extraction: 3112821789_1f7c3bbb99.jpg
# feature extraction: 3155451946_c0862c70cb.jpg
# feature extraction: 3122497129_d08f5729b8.jpg
# feature extraction: 3172283002_3c0fc624de.jpg
# feature extraction: 3107368071_724613fc4f.jpg
# feature extraction: 3155279929_d1cddbe7cf.jpg
# feature extraction: 3120266797_47e7d91614.jpg
# feature extraction: 3107558821_f3b205d4ed.jpg
# feature extraction: 3127142756_bf0bfcb571.jpg
# feature extraction: 3131160589_dc73c209b7.jpg
# feature extraction: 3163273640_8d3ef22eaf.jpg
# feature extraction: 3168796547_0c14b368f9.jpg
# feature extraction: 3128856481_86e5df4160.jpg
# feature extraction: 3132760860_3e743a935d.jpg
# feature extraction: 3160531982_37f5636b8a.jpg
# feature extraction: 3153067758_53f003b1df.jpg
# feature extraction: 3107463441_7c68606450.jpg
# feature extraction: 3163477256_073605e06e.jpg
# feature extraction: 3110018626_307a123b59.jpg
# feature extraction: 3165123595_8db9f918bf.jpg
# feature extraction: 3157220149_cc3c8cc84d.jpg
# feature extraction: 3147758035_e8a70818cb.jpg
# feature extraction: 3109688427_d2e702456c.jpg
# feature extraction: 3107592525_0bcd00777e.jpg
# feature extraction: 3134341610_3c55e373a7.jpg
# feature extraction: 3164415865_612f9fd8bc.jpg
# feature extraction: 3168841415_c0705a327a.jpg
# feature extraction: 3156113206_53c2a7b5d8.jpg
# feature extraction: 3162095736_cc41dd41ff.jpg
# feature extraction: 3122938209_2b2c6c1fab.jpg
# feature extraction: 3170110692_d1e0e66cee.jpg
# feature extraction: 3166969425_b5ace2f9c2.jpg
# feature extraction: 315125146_d9a8e60061.jpg
# feature extraction: 3119076670_64b5340530.jpg
# feature extraction: 3168123064_d1983b8f92.jpg
# feature extraction: 312427606_defa0dfaa8.jpg
# feature extraction: 3150742439_b8a352e1e0.jpg
# feature extraction: 3121521593_18f0ec14f7.jpg
# feature extraction: 3165826902_6bf9c4bdb2.jpg
# feature extraction: 3143953179_1c08c023a5.jpg
# feature extraction: 3120189281_1938460e85.jpg
# feature extraction: 3156406419_38fbd52007.jpg
# feature extraction: 316577571_27a0e0253e.jpg
# feature extraction: 3155657768_b83a7831e5.jpg
# feature extraction: 3120953244_b00b152246.jpg
# feature extraction: 3113682377_14fc7b62b0.jpg
# feature extraction: 3172384527_b107385a20.jpg
# feature extraction: 3135504530_0f4130d8f8.jpg
# feature extraction: 3134092148_151154139a.jpg
# feature extraction: 3139160252_75109e9e05.jpg
# feature extraction: 3161044966_27bf6f9dec.jpg
# feature extraction: 3157622277_9f59b4f62f.jpg
# feature extraction: 3173461705_b5cdeef1eb.jpg
# feature extraction: 3146232740_df3da0163b.jpg
# feature extraction: 3159995270_17334ccb5b.jpg
# feature extraction: 3164423279_9b27cb6a06.jpg
# feature extraction: 3125041578_c1f2d73b6d.jpg
# feature extraction: 3163198309_bbfe504f0a.jpg
# feature extraction: 3111402233_6285bcba7a.jpg
# feature extraction: 3139238055_2817a0c7d8.jpg
# feature extraction: 3106857210_07a92577fc.jpg
# feature extraction: 3137061312_eb5fdcf3fd.jpg
# feature extraction: 3132832452_c354c6396c.jpg
# feature extraction: 3108544687_c7115823f5.jpg
# feature extraction: 3164347907_2813f8ff0b.jpg
# feature extraction: 3133044777_8cc930a4ec.jpg
# feature extraction: 3115174046_9e96b9ce47.jpg
# feature extraction: 3126225245_96cd2c053f.jpg
# feature extraction: 3110174991_a4b05f8a46.jpg
# feature extraction: 3155987659_b9ea318dd3.jpg
# feature extraction: 3136404885_f4d8f1d15a.jpg
# feature extraction: 3125158798_0743dae56e.jpg
# feature extraction: 3135826945_f7c741e5b7.jpg
# feature extraction: 3162442331_c9711857c6.jpg
# feature extraction: 3142055158_01b9e4caa4.jpg
# feature extraction: 3154528397_89112faf4b.jpg
# feature extraction: 3113769557_9edbb8275c.jpg
# feature extraction: 315436114_6d386b8c36.jpg
# feature extraction: 3106883334_419f3fb16f.jpg
# feature extraction: 3126681108_f88128699c.jpg
# feature extraction: 3145869775_85dfae43bd.jpg
# feature extraction: 3111208043_dbe8e87fa1.jpg
# feature extraction: 310715139_7f05468042.jpg
# feature extraction: 3146937399_8c046b7b1a.jpg
# feature extraction: 3134585858_a8c3493ca5.jpg
# feature extraction: 3119903318_d032141839.jpg
# feature extraction: 3166366760_e43cf66eda.jpg
# feature extraction: 3138562460_44227a35cf.jpg
# feature extraction: 3170802797_3c851bb475.jpg
# feature extraction: 3154693053_cfcd05c226.jpg
# feature extraction: 3148647065_2d6cd88cf6.jpg
# feature extraction: 3117336911_a729f42869.jpg
# feature extraction: 3130093622_362f32f2bb.jpg
# feature extraction: 3173215794_6bdd1f72d4.jpg
# feature extraction: 3171347658_f0d5469c56.jpg
# feature extraction: 3171035252_dba286ae5c.jpg
# feature extraction: 3167365436_c379bda282.jpg
# feature extraction: 3108378861_d2214d971e.jpg
# feature extraction: 3147217787_ed21cd4990.jpg
# feature extraction: 3208032657_27b9d6c4f3.jpg
# feature extraction: 3211577298_14296db6fd.jpg
# feature extraction: 3209564153_077ed4d246.jpg
# feature extraction: 3198231851_6b1727482b.jpg
# feature extraction: 3189002057_3ef61b803e.jpg
# feature extraction: 3207676216_48478bce97.jpg
# feature extraction: 3204686006_88f04547b9.jpg
# feature extraction: 3188319076_71724fcc07.jpg
# feature extraction: 3199460792_deef518c01.jpg
# feature extraction: 3205839744_24504ba179.jpg
# feature extraction: 3208074567_ac44aeb3f3.jpg
# feature extraction: 3183875944_b2be694e06.jpg
# feature extraction: 319938879_daf0857f91.jpg
# feature extraction: 3192311620_99bda27fbd.jpg
# feature extraction: 3178599352_c57fdebcd2.jpg
# feature extraction: 3207343907_995f7ac1d2.jpg
# feature extraction: 3211289105_e0360a9c7f.jpg
# feature extraction: 3190677999_60bbd330fd.jpg
# feature extraction: 318070878_92ead85868.jpg
# feature extraction: 3182558164_488b819f14.jpg
# feature extraction: 3173928684_4ea0ee5114.jpg
# feature extraction: 319185571_56162796da.jpg
# feature extraction: 3174453534_fcc927c647.jpg
# feature extraction: 3217187564_0ffd89dec1.jpg
# feature extraction: 3177799416_5bd0382370.jpg
# feature extraction: 3211210739_3dea005fde.jpg
# feature extraction: 3216901052_269ace7b3c.jpg
# feature extraction: 3206919175_e3a11b6874.jpg
# feature extraction: 3185787277_b412d7f5b7.jpg
# feature extraction: 3209620285_edfc479392.jpg
# feature extraction: 3216926094_bc975e84b9.jpg
# feature extraction: 3217240672_b99a682026.jpg
# feature extraction: 3214579977_fa9fb006a6.jpg
# feature extraction: 3211029717_2affe6bbd5.jpg
# feature extraction: 3197482764_2f289cb726.jpg
# feature extraction: 3207775692_bb897d9afd.jpg
# feature extraction: 3189941492_a3f4347b1a.jpg
# feature extraction: 3201594926_cd2009eb13.jpg
# feature extraction: 3186556417_b2d6921a20.jpg
# feature extraction: 3201666946_04fe837aff.jpg
# feature extraction: 319847657_2c40e14113.jpg
# feature extraction: 3208571574_6dc1a461c5.jpg
# feature extraction: 3183195653_11b66acb34.jpg
# feature extraction: 3189307452_aebc12380b.jpg
# feature extraction: 3215695965_69fbeba3d5.jpg
# feature extraction: 3210457502_c6030ce567.jpg
# feature extraction: 3179336562_c3d0c0a3bd.jpg
# feature extraction: 3193335577_9bdbaf9f70.jpg
# feature extraction: 3207264553_8cd4dcde53.jpg
# feature extraction: 3209350613_eb86579ee8.jpg
# feature extraction: 3216085740_699c2ce1ae.jpg
# feature extraction: 3189293145_35dea42679.jpg
# feature extraction: 3215081286_d55541aa6b.jpg
# feature extraction: 3218481970_1fa627b3da.jpg
# feature extraction: 3208553539_2bf6c6d162.jpg
# feature extraction: 3181328245_7c04ce1691.jpg
# feature extraction: 3187395715_f2940c2b72.jpg
# feature extraction: 3181599388_68559cfc17.jpg
# feature extraction: 3205754736_32c29b5208.jpg
# feature extraction: 3176968956_d942a93513.jpg
# feature extraction: 3183195185_cd0ff994a1.jpg
# feature extraction: 3192069971_83c5a90b4c.jpg
# feature extraction: 3208999896_dab42dc40b.jpg
# feature extraction: 3180806542_49b6de312d.jpg
# feature extraction: 3195188609_01afbe46e6.jpg
# feature extraction: 3185645793_49de805194.jpg
# feature extraction: 317383917_d8bfa350b6.jpg
# feature extraction: 3213622536_31da7f6682.jpg
# feature extraction: 319869052_08b000e4af.jpg
# feature extraction: 3198962089_e647d1b0cd.jpg
# feature extraction: 3204354161_caf89ec784.jpg
# feature extraction: 3210419174_d083a16f77.jpg
# feature extraction: 3191135894_2b4bdabb6d.jpg
# feature extraction: 3215847501_c723905ba4.jpg
# feature extraction: 3182996527_70d9c323d5.jpg
# feature extraction: 3219210794_4324df188b.jpg
# feature extraction: 3217056901_fe2c70377d.jpg
# feature extraction: 3187492926_8aa85f80c6.jpg
# feature extraction: 3203872773_6c30f64be3.jpg
# feature extraction: 3217620013_8b17873273.jpg
# feature extraction: 3215315009_47577bf8f7.jpg
# feature extraction: 3207654194_43d6bebd68.jpg
# feature extraction: 3191027142_33e86636ca.jpg
# feature extraction: 3203908917_53e53c03d1.jpg
# feature extraction: 3184891327_8785194e3c.jpg
# feature extraction: 3198237818_cb5eb302f0.jpg
# feature extraction: 3215117062_6e07a86352.jpg
# feature extraction: 318667317_108c402140.jpg
# feature extraction: 3197791645_601908f26b.jpg
# feature extraction: 3217909454_7baa0edbb2.jpg
# feature extraction: 3195969533_98f5de0fab.jpg
# feature extraction: 3175849727_bf30b892cb.jpg
# feature extraction: 3184206563_5435f2b494.jpg
# feature extraction: 3202360797_2084743e90.jpg
# feature extraction: 3184112120_6ddcd98016.jpg
# feature extraction: 3177468217_56a9142e46.jpg
# feature extraction: 3213992947_3f3f967a9f.jpg
# feature extraction: 3215108916_0473007b47.jpg
# feature extraction: 3209523192_05a4cef844.jpg
# feature extraction: 3211556865_d1d9becf69.jpg
# feature extraction: 3204712107_5a06a81002.jpg
# feature extraction: 3211437611_bd4af3730b.jpg
# feature extraction: 3214885227_2be09e7cfb.jpg
# feature extraction: 3220140234_e072856e6c.jpg
# feature extraction: 3184031654_34b5c4ffe1.jpg
# feature extraction: 3214237686_6566b8b52f.jpg
# feature extraction: 3176498130_52ab9460b2.jpg
# feature extraction: 3186412658_2ab2ebd397.jpg
# feature extraction: 3177298173_78cea31d64.jpg
# feature extraction: 3200120942_59cfbb3437.jpg
# feature extraction: 317488612_70ac35493b.jpg
# feature extraction: 3218480482_66af7587c8.jpg
# feature extraction: 3185409663_95f6b958d8.jpg
# feature extraction: 3216829599_366a43f05e.jpg
# feature extraction: 3178371973_60c6b8f110.jpg
# feature extraction: 3178005751_fca19815ac.jpg
# feature extraction: 3211199368_ca78387f72.jpg
# feature extraction: 3187117682_986ffd6b67.jpg
# feature extraction: 3204525212_d548c7fca7.jpg
# feature extraction: 3217266166_4e0091860b.jpg
# feature extraction: 3187096035_65dc416291.jpg
# feature extraction: 319870744_0e0138d205.jpg
# feature extraction: 3182405529_7692256746.jpg
# feature extraction: 3195701071_81879257f5.jpg
# feature extraction: 3174726084_c108de0a64.jpg
# feature extraction: 3186527735_6e9fe2cf88.jpg
# feature extraction: 3206999917_e682672cbc.jpg
# feature extraction: 3215896272_e9b4b547a9.jpg
# feature extraction: 3214381315_b54f5c9be4.jpg
# feature extraction: 3203878596_cbb307ce3b.jpg
# feature extraction: 3186863842_5832573c5e.jpg
# feature extraction: 3185371756_ff4e9fa8a6.jpg
# feature extraction: 3197981073_3156963446.jpg
# feature extraction: 3220009216_10f088185e.jpg
# feature extraction: 3211453055_05cbfe37cd.jpg
# feature extraction: 3214573346_d3a57f0328.jpg
# feature extraction: 3189521080_133777bce5.jpg
# feature extraction: 3216762979_813c45a8ec.jpg
# feature extraction: 3220151692_d398ef9779.jpg
# feature extraction: 3203453897_6317aac6ff.jpg
# feature extraction: 3175446111_681a89f873.jpg
# feature extraction: 3219122000_bd6b4ae5ff.jpg
# feature extraction: 3185695861_86152b2755.jpg
# feature extraction: 3212456649_40a3052682.jpg
# feature extraction: 319851847_7212423309.jpg
# feature extraction: 3215870337_c92a1a1b2f.jpg
# feature extraction: 3183777589_460a4f445b.jpg
# feature extraction: 3199895624_4f01798c6f.jpg
# feature extraction: 3203742047_6a55065411.jpg
# feature extraction: 3197247245_9c93b60b8a.jpg
# feature extraction: 3196100539_102fe877b3.jpg
# feature extraction: 3189251454_03b76c2e92.jpg
# feature extraction: 3217291172_10ef70af88.jpg
# feature extraction: 3219065971_702c4e8c34.jpg
# feature extraction: 3217910740_d1d61c08ab.jpg
# feature extraction: 3203707977_cc9448fecb.jpg
# feature extraction: 3206058778_7053ee6b52.jpg
# feature extraction: 3213395965_2a823c6865.jpg
# feature extraction: 3182258223_5b9c8a8c55.jpg
# feature extraction: 3188044631_ca3a9cc737.jpg
# feature extraction: 3188036349_8e4e2d6ca8.jpg
# feature extraction: 3178300150_d4605ff02c.jpg
# feature extraction: 3199645963_a681fe04f8.jpg
# feature extraction: 3187364311_4c2a87083b.jpg
# feature extraction: 3212085754_35fdc9ccaa.jpg
# feature extraction: 3174431688_ae84778db0.jpg
# feature extraction: 3187924573_203223e6c0.jpg
# feature extraction: 3179952488_c1c812a03b.jpg
# feature extraction: 3204922011_185e48949a.jpg
# feature extraction: 3193511842_82549c21fb.jpg
# feature extraction: 321229104_3cbaf0f51c.jpg
# feature extraction: 3207358897_bfa61fa3c6.jpg
# feature extraction: 3211581957_df2f7e2236.jpg
# feature extraction: 3174417550_d2e6100278.jpg
# feature extraction: 3176072448_b84c99cf7f.jpg
# feature extraction: 3205336477_037d4b6bd9.jpg
# feature extraction: 3182570190_48214e54c7.jpg
# feature extraction: 3220126881_b0a4f7cccb.jpg
# feature extraction: 3174228611_6cf9d2266b.jpg
# feature extraction: 3204081508_0e7f408097.jpg
# feature extraction: 3205214191_29b42b9b09.jpg
# feature extraction: 3185662156_c877583c53.jpg
# feature extraction: 3197917064_e679a44b8e.jpg
# feature extraction: 3215238223_29de2b35cb.jpg
# feature extraction: 3198247669_7493af04a7.jpg
# feature extraction: 3181322965_ce9da15271.jpg
# feature extraction: 3195147187_a073d59fa8.jpg
# feature extraction: 3183883750_b6acc40397.jpg
# feature extraction: 3196995975_3e38eabf01.jpg
# feature extraction: 3174156702_95a1cda2d9.jpg
# feature extraction: 3183060123_ea3af6278b.jpg
# feature extraction: 3197891333_b1b0fd1702.jpg
# feature extraction: 3201427741_3033f5b625.jpg
# feature extraction: 3218861747_5c5c547b66.jpg
# feature extraction: 3212465975_b657f40eed.jpg
# feature extraction: 3214151585_f2d0b00b41.jpg
# feature extraction: 3210359094_ee51285301.jpg
# feature extraction: 3181701312_70a379ab6e.jpg
# feature extraction: 3218889785_86cb64014f.jpg
# feature extraction: 3212625256_685bc4de99.jpg
# feature extraction: 3217893350_57be430d06.jpg
# feature extraction: 3174196837_800689a2f3.jpg
# feature extraction: 3208987435_780ae35ef0.jpg
# feature extraction: 320093980_5388cb3733.jpg
# feature extraction: 3194134352_bc1b2a25d7.jpg
# feature extraction: 3182161610_4d349b257f.jpg
# feature extraction: 3175712926_5a470d0886.jpg
# feature extraction: 3176131893_7181c733aa.jpg
# feature extraction: 3176278670_195eea071c.jpg
# feature extraction: 3195040792_a03954a19f.jpg
# feature extraction: 3202255152_08973fa3d7.jpg
# feature extraction: 3176277818_235486a3cd.jpg
# feature extraction: 3175434849_859f09fe07.jpg
# feature extraction: 3189964753_a95536ced9.jpg
# feature extraction: 3191805046_77c334b506.jpg
# feature extraction: 3181409177_edb09c2718.jpg
# feature extraction: 3210705660_2b14b7fb36.jpg
# feature extraction: 3214100656_80cda1b86b.jpg
# feature extraction: 3182121297_38c99b2769.jpg
# feature extraction: 3208188198_2b271d2a2e.jpg
# feature extraction: 3173976185_8a50123050.jpg
# feature extraction: 3178489390_13a6ae7524.jpg
# feature extraction: 3191982761_88793192ed.jpg
# feature extraction: 319847643_df7c2a1d25.jpg
# feature extraction: 3192266178_f9bf5d3dba.jpg
# feature extraction: 3183519385_311555d5f5.jpg
# feature extraction: 3186073578_6e115f45f5.jpg
# feature extraction: 3211316116_a2462e327d.jpg
# feature extraction: 3174713468_e22fa7779e.jpg
# feature extraction: 317641829_ab2607a6c0.jpg
# feature extraction: 3209966887_5b744bd050.jpg
# feature extraction: 3223709894_97824ba76f.jpg
# feature extraction: 3249125548_700d874380.jpg
# feature extraction: 3243591844_791cfa62eb.jpg
# feature extraction: 3225058391_a12d38d911.jpg
# feature extraction: 3247598959_5b2348444c.jpg
# feature extraction: 3228960484_9aab98b91a.jpg
# feature extraction: 3252985078_c4ee2aca4e.jpg
# feature extraction: 3254817653_632e840423.jpg
# feature extraction: 3242263536_a436f19257.jpg
# feature extraction: 3250589803_3f440ba781.jpg
# feature extraction: 3224904543_679fe05c41.jpg
# feature extraction: 3239021459_a6b71bb400.jpg
# feature extraction: 3238654429_d899e34287.jpg
# feature extraction: 3240090389_97a8c5d386.jpg
# feature extraction: 3249062399_0dafe5e4f5.jpg
# feature extraction: 3254662117_b2e7dede6e.jpg
# feature extraction: 325005410_e1ff5041b5.jpg
# feature extraction: 3249865395_dceaa59f54.jpg
# feature extraction: 3220200084_3ea129336e.jpg
# feature extraction: 3249014584_21dd9ddd9d.jpg
# feature extraction: 3245939062_8ffe1d2be5.jpg
# feature extraction: 3231237864_8cb1c6d863.jpg
# feature extraction: 3229442620_fd47d01b59.jpg
# feature extraction: 3244747165_17028936e0.jpg
# feature extraction: 3225037367_a71fa86319.jpg
# feature extraction: 3223973114_6c15538ce9.jpg
# feature extraction: 3247693965_845b3b4349.jpg
# feature extraction: 3240014971_ee2ea8406f.jpg
# feature extraction: 3243020805_2bafc36c45.jpg
# feature extraction: 3242354561_54e5a34925.jpg
# feature extraction: 3245266444_2e798096e6.jpg
# feature extraction: 324355356_859988a710.jpg
# feature extraction: 3256043809_47258e0b3e.jpg
# feature extraction: 322103537_184367bf88.jpg
# feature extraction: 3232470286_903a61ea16.jpg
# feature extraction: 3242007318_01e82171aa.jpg
# feature extraction: 3227499174_07feb26337.jpg
# feature extraction: 322050103_145f7233c6.jpg
# feature extraction: 3240351042_5d29c94b0e.jpg
# feature extraction: 3253060519_55d98c208f.jpg
# feature extraction: 324208502_674488bcea.jpg
# feature extraction: 3231596071_f0c522a639.jpg
# feature extraction: 3222041930_f642f49d28.jpg
# feature extraction: 3231575742_31732664cf.jpg
# feature extraction: 3229730008_63f8ca2de2.jpg
# feature extraction: 3244910944_612b8ce98f.jpg
# feature extraction: 3240048764_acce8af2a5.jpg
# feature extraction: 3220161734_77f42734b9.jpg
# feature extraction: 3243094580_ccd01679f5.jpg
# feature extraction: 3225226381_9fe306fb9e.jpg
# feature extraction: 3256456935_664a7a5bba.jpg
# feature extraction: 3251460982_4578a568bb.jpg
# feature extraction: 3235746553_a40416c00e.jpg
# feature extraction: 3248352729_ab264b2222.jpg
# feature extraction: 3225025519_c089c14559.jpg
# feature extraction: 3249278583_95cd8206da.jpg
# feature extraction: 3243588540_b418ac7eda.jpg
# feature extraction: 3255737244_1f8948fc07.jpg
# feature extraction: 3255620561_7644747791.jpg
# feature extraction: 3222055946_45f7293bb2.jpg
# feature extraction: 3240094420_a9eea11d39.jpg
# feature extraction: 3243233886_235a80e8c7.jpg
# feature extraction: 3246190363_68d903bfcb.jpg
# feature extraction: 3222749441_3bdfe088e3.jpg
# feature extraction: 3256275785_9c3af57576.jpg
# feature extraction: 3244586044_205d5ae2ba.jpg
# feature extraction: 3241892328_4ebf8b21ce.jpg
# feature extraction: 3251648670_9339943ba2.jpg
# feature extraction: 3252588185_3210fe94be.jpg
# feature extraction: 3228793611_8f260ea500.jpg
# feature extraction: 3229282764_a4a515f4e2.jpg
# feature extraction: 3240558825_cd859d6230.jpg
# feature extraction: 3250695024_93e8ab7305.jpg
# feature extraction: 3238951136_2a99f1a1a8.jpg
# feature extraction: 3235542079_2fcf4951a1.jpg
# feature extraction: 3256274183_4eab3b2322.jpg
# feature extraction: 3247052319_da8aba1983.jpg
# feature extraction: 3251234434_d01e25a50a.jpg
# feature extraction: 3242718240_3358f2d6e6.jpg
# feature extraction: 3228517564_74b00a923b.jpg
# feature extraction: 3250593457_9049a73b61.jpg
# feature extraction: 3229821595_77ace81c6b.jpg
# feature extraction: 3242919570_39a05aa2ee.jpg
# feature extraction: 3246804978_ea2c9e56f2.jpg
# feature extraction: 3231751379_10ebf7150c.jpg
# feature extraction: 3239480519_22540b5016.jpg
# feature extraction: 3241726740_6d256d61ec.jpg
# feature extraction: 3225310099_d8e419ba56.jpg
# feature extraction: 3245912109_fdeef6b456.jpg
# feature extraction: 3254645823_a7c072481c.jpg
# feature extraction: 3239866450_3f8cfb0c83.jpg
# feature extraction: 3226796100_08c49cfa5c.jpg
# feature extraction: 3225880532_c8d5d1d798.jpg
# feature extraction: 3224578187_749882c17f.jpg
# feature extraction: 3231880001_193a579b97.jpg
# feature extraction: 3234890865_bb3c316968.jpg
# feature extraction: 3247500085_c4f641aa84.jpg
# feature extraction: 3223224391_be50bf4f43.jpg
# feature extraction: 3251088971_f4471048e3.jpg
# feature extraction: 3224560800_8fefd52510.jpg
# feature extraction: 3242088278_43eea5d17e.jpg
# feature extraction: 3227148358_f152303584.jpg
# feature extraction: 3244734844_c318c29c23.jpg
# feature extraction: 3247423890_163f00a2cb.jpg
# feature extraction: 3245504245_27931f5ec1.jpg
# feature extraction: 3251646144_d9f4ccca3f.jpg
# feature extraction: 323657582_b6b6d8f7bd.jpg
# feature extraction: 3246991821_750a3097e2.jpg
# feature extraction: 3221815947_76c95b50b7.jpg
# feature extraction: 3230132205_dccfafa5ee.jpg
# feature extraction: 3252457866_b86614064c.jpg
# feature extraction: 3244171699_ace4b5d999.jpg
# feature extraction: 3229519418_040f05ced1.jpg
# feature extraction: 3222496967_45d468ee66.jpg
# feature extraction: 3225478803_f7a9a41a1d.jpg
# feature extraction: 3247168324_c45eaf734d.jpg
# feature extraction: 3220650628_4ed964e5b4.jpg
# feature extraction: 3227423095_5049951eab.jpg
# feature extraction: 3249738122_decde6c117.jpg
# feature extraction: 3244470342_c08f6bb17e.jpg
# feature extraction: 3227111573_c82f7d68b1.jpg
# feature extraction: 3255017708_2b02bfcdcf.jpg
# feature extraction: 3255482333_5bcee79f7e.jpg
# feature extraction: 3255732353_fbc487aefc.jpg
# feature extraction: 3251906388_c09d44340e.jpg
# feature extraction: 3249891130_b241591e89.jpg
# feature extraction: 3249891874_6a090ef097.jpg
# feature extraction: 3247341210_5d1e50df23.jpg
# feature extraction: 3229898555_16877f5180.jpg
# feature extraction: 3245070961_8977fdd548.jpg
# feature extraction: 3227140905_1d7e30e4c4.jpg
# feature extraction: 3248220732_0f173fc197.jpg
# feature extraction: 3221128704_d1205db79b.jpg
# feature extraction: 3222702477_34d2d24f1f.jpg
# feature extraction: 3234115903_f4dfc8fc75.jpg
# feature extraction: 3235076435_1eaa40bd0a.jpg
# feature extraction: 3245250964_9d3e37111e.jpg
# feature extraction: 3223809913_ae15d14d9a.jpg
# feature extraction: 3250076419_eb3de15063.jpg
# feature extraction: 3234719720_5bb2fc5ffa.jpg
# feature extraction: 3245460937_2710a82709.jpg
# feature extraction: 3226541300_6c81711e8e.jpg
# feature extraction: 322791392_aa3b142f43.jpg
# feature extraction: 3229913073_e7857a5966.jpg
# feature extraction: 3248408149_41a8dd90d3.jpg
# feature extraction: 3248752274_96740ed073.jpg
# feature extraction: 3225998968_ef786d86e0.jpg
# feature extraction: 3251976937_20625dc2b8.jpg
# feature extraction: 3241965735_8742782a70.jpg
# feature extraction: 3236677456_75821e3583.jpg
# feature extraction: 3224227640_31865b3651.jpg
# feature extraction: 3236447445_eecafdf4f0.jpg
# feature extraction: 3237760601_5334f3f3b5.jpg
# feature extraction: 3226254560_2f8ac147ea.jpg
# feature extraction: 3223606402_bb2aa6db95.jpg
# feature extraction: 3241487502_f4f0cc4a8a.jpg
# feature extraction: 3221036999_3f7b152d8a.jpg
# feature extraction: 3254640083_eb34b8edfe.jpg
# feature extraction: 3246773992_89bf86937b.jpg
# feature extraction: 3234401637_84e0d14414.jpg
# feature extraction: 3227594168_3351722aae.jpg
# feature extraction: 3222250187_ef610f267e.jpg
# feature extraction: 3234375022_1464ea7f8a.jpg
# feature extraction: 3242808166_8638150274.jpg
# feature extraction: 3225296260_2ee72b4917.jpg
# feature extraction: 3222842866_cb85243ce4.jpg
# feature extraction: 325576658_59f68bdbd6.jpg
# feature extraction: 3232030272_b2480a5fe7.jpg
# feature extraction: 3223302125_f8154417f4.jpg
# feature extraction: 3249597269_935e0a375a.jpg
# feature extraction: 3223055565_68973f5d20.jpg
# feature extraction: 3232252882_05db7c2216.jpg
# feature extraction: 3228069008_edb2961fc4.jpg
# feature extraction: 3256272547_5ae6c66293.jpg
# feature extraction: 3230101918_7d81cb0fc8.jpg
# feature extraction: 3259002340_707ce96858.jpg
# feature extraction: 3259579174_30a8a27058.jpg
# feature extraction: 326028454_fb396167e6.jpg
# feature extraction: 3259992722_4c5e895734.jpg
# feature extraction: 3259992164_94600858b3.jpg
# feature extraction: 3259225196_750c4ce0f9.jpg
# feature extraction: 3259694057_fae7484b0a.jpg
# feature extraction: 3259992638_0612a40288.jpg
# feature extraction: 3258391809_38fc6211f7.jpg
# feature extraction: 3257182199_5fda78d870.jpg
# feature extraction: 3258396041_69717247f7.jpg
# feature extraction: 3259222980_04fb62df97.jpg
# feature extraction: 3259229498_2b5708c0c6.jpg
# feature extraction: 3257107194_f235c8f7ab.jpg
# feature extraction: 3259160693_067ec7ebc3.jpg
# feature extraction: 3260214530_7179346407.jpg
# feature extraction: 3257277774_aba333a94c.jpg
# feature extraction: 3260191163_6c1551eee8.jpg
# feature extraction: 3258397351_1a70f1993d.jpg
# feature extraction: 3258394043_a0b6a94dce.jpg
# feature extraction: 3256603992_67312b5a36.jpg
# feature extraction: 3259110412_9908c45144.jpg
# feature extraction: 3260088697_af9b6d2393.jpg
# feature extraction: 3259228898_cefd04580b.jpg
# feature extraction: 3259883609_6a1b46919e.jpg
# feature extraction: 3259757648_71edb4347b.jpg
# feature extraction: 3260975858_75d0612a69.jpg
# feature extraction: 3260768565_2b725be090.jpg
# feature extraction: 3259991972_fce3ab18b2.jpg
# feature extraction: 3258395783_2de3a4ba27.jpg
# feature extraction: 3259666643_ae49524c81.jpg
# feature extraction: 3258472448_75cfab5e6f.jpg
# feature extraction: 3258874419_23fec1bdc1.jpg
# feature extraction: 3259119085_21613b69df.jpg
# feature extraction: 3259231890_16fe167b31.jpg
# feature extraction: 3257103624_e76f25ff9e.jpg
# feature extraction: 3259222690_69737f2a6e.jpg
# feature extraction: 3257207516_9d2bc0ea04.jpg
# feature extraction: 3261493263_381a4c5cc7.jpg
# feature extraction: 3262386960_14f5d857db.jpg
# feature extraction: 3262793378_773b21ec19.jpg
# feature extraction: 3262760716_1e9734f5ba.jpg
# feature extraction: 3262301835_9f1a49b80a.jpg
# feature extraction: 3262849619_0bc4f88ef9.jpg
# feature extraction: 3262475923_f1f77fcd9f.jpg
# feature extraction: 3262075846_5695021d84.jpg
# feature extraction: 3261666285_86fceb762d.jpg
# feature extraction: 3262647146_a53770a21d.jpg
# feature extraction: 3268191118_ba25fabab6.jpg
# feature extraction: 3293751136_b0ce285dc3.jpg
# feature extraction: 3273403495_fcd09c453e.jpg
# feature extraction: 3283626303_8e23d4a842.jpg
# feature extraction: 3300019891_8f404d94a1.jpg
# feature extraction: 3307978046_92fef4dfa9.jpg
# feature extraction: 3295680663_af21ea648b.jpg
# feature extraction: 3303797949_339bb969ba.jpg
# feature extraction: 3310067561_b92017acab.jpg
# feature extraction: 3301854980_233cc2f896.jpg
# feature extraction: 3277162496_dff7eeb59e.jpg
# feature extraction: 3281611946_f42deed2e1.jpg
# feature extraction: 3301754574_465af5bf6d.jpg
# feature extraction: 3287963317_186491ee78.jpg
# feature extraction: 3297323827_f582356478.jpg
# feature extraction: 3294964868_16f4f9fa9d.jpg
# feature extraction: 3263741906_6e4508d1c8.jpg
# feature extraction: 3270083123_fcc1208053.jpg
# feature extraction: 3267644370_f2728d6c7a.jpg
# feature extraction: 3296584432_bef3c965a3.jpg
# feature extraction: 3286045254_696c6b15bd.jpg
# feature extraction: 3278189732_f750cb26b7.jpg
# feature extraction: 3304484212_b950233c30.jpg
# feature extraction: 3271084924_4778d556cc.jpg
# feature extraction: 3290105461_7590f23371.jpg
# feature extraction: 3290465391_258429e2f9.jpg
# feature extraction: 3285298241_9b1ed98d19.jpg
# feature extraction: 3280644151_3d89cb1e0e.jpg
# feature extraction: 3307077951_dd31f1971c.jpg
# feature extraction: 3272847211_9e8a4f8308.jpg
# feature extraction: 3275527950_41aca690a1.jpg
# feature extraction: 3306464579_1b16a0caf2.jpg
# feature extraction: 3277824093_299cbb3138.jpg
# feature extraction: 3265578645_4044a7049a.jpg
# feature extraction: 3264337159_e1680a35ba.jpg
# feature extraction: 3278581900_8ce75a5332.jpg
# feature extraction: 3268407162_6274e0f74f.jpg
# feature extraction: 3286111436_891ae7dab9.jpg
# feature extraction: 3296226598_1c892c4351.jpg
# feature extraction: 3263946591_a1558b77d3.jpg
# feature extraction: 3274691778_94bb57bba3.jpg
# feature extraction: 3291255271_a185eba408.jpg
# feature extraction: 3298199743_d8dd8f94a0.jpg
# feature extraction: 3273325447_81c94000da.jpg
# feature extraction: 3284955091_59317073f0.jpg
# feature extraction: 3286193613_fc046e8016.jpg
# feature extraction: 3304712466_18cbdb85fe.jpg
# feature extraction: 3282634762_2650d0088a.jpg
# feature extraction: 3298233193_d2a550840d.jpg
# feature extraction: 3301822808_f2ccff86f4.jpg
# feature extraction: 3301811927_a2797339e5.jpg
# feature extraction: 3266406566_d64e57e65a.jpg
# feature extraction: 3284887033_e2e48f1863.jpg
# feature extraction: 3286406057_a1668655af.jpg
# feature extraction: 3308018795_68a97a425c.jpg
# feature extraction: 3303648823_53cf750acd.jpg
# feature extraction: 3263141261_db3a4798b5.jpg
# feature extraction: 3304556387_203b9d4db0.jpg
# feature extraction: 3284899112_f11ab3cfe6.jpg
# feature extraction: 3306951622_93b82cac21.jpg
# feature extraction: 3263497678_8bb688ca01.jpg
# feature extraction: 3294202771_e8ee78a439.jpg
# feature extraction: 3293751640_d81a6f3a0c.jpg
# feature extraction: 326456451_effadbbe49.jpg
# feature extraction: 3266306177_7994dc2865.jpg
# feature extraction: 3296500180_0d7a6650dc.jpg
# feature extraction: 3264397357_72f084cac1.jpg
# feature extraction: 3287236038_8998e6b82f.jpg
# feature extraction: 3293018193_e4e0c8db7c.jpg
# feature extraction: 3286222970_1fa445e38f.jpg
# feature extraction: 3295391572_cbfde03a10.jpg
# feature extraction: 3281580623_8c3ba0fdb2.jpg
# feature extraction: 3288839246_fdb00395ae.jpg
# feature extraction: 3301859683_2d5e4b40a3.jpg
# feature extraction: 3270047169_2ed289a9af.jpg
# feature extraction: 3285180819_a9712fd2bc.jpg
# feature extraction: 3266261886_36e1323d2f.jpg
# feature extraction: 3271252073_0a1b9525fc.jpg
# feature extraction: 3264937930_9623496b64.jpg
# feature extraction: 3305767464_d64a336f60.jpg
# feature extraction: 3272541970_ac0f1de274.jpg
# feature extraction: 3294830188_e46bd9b93c.jpg
# feature extraction: 3295418287_5d590dac43.jpg
# feature extraction: 3307667255_26bede91eb.jpg
# feature extraction: 3296715418_29542dcdc2.jpg
# feature extraction: 3306212559_731ba9bd05.jpg
# feature extraction: 3310551665_15b79ef4ea.jpg
# feature extraction: 3269895626_7b253c82ed.jpg
# feature extraction: 3289817083_4e78e1c05a.jpg
# feature extraction: 3309082580_7228067ee0.jpg
# feature extraction: 3268443910_b36dbc1e5c.jpg
# feature extraction: 330849796_c575c3108a.jpg
# feature extraction: 3285993030_87b0f1d202.jpg
# feature extraction: 3287549827_04dec6fb6e.jpg
# feature extraction: 3293753378_7a8ddb98b2.jpg
# feature extraction: 3288173388_03bc2a844d.jpg
# feature extraction: 3265209567_b3b9c8e0fe.jpg
# feature extraction: 3294717824_3bb7b5d1c8.jpg
# feature extraction: 3269087421_1d489abeae.jpg
# feature extraction: 3284460070_6805990149.jpg
# feature extraction: 3286198467_8880be127e.jpg
# feature extraction: 3271061953_700b96520c.jpg
# feature extraction: 327997381_55f90dc834.jpg
# feature extraction: 3279025792_23bfd21bcc.jpg
# feature extraction: 3287904625_f68ca5cea7.jpg
# feature extraction: 3304511635_113beaf458.jpg
# feature extraction: 3309042087_ee96d94b8a.jpg
# feature extraction: 3279988814_d3693dcb6c.jpg
# feature extraction: 3283368342_b96d45210e.jpg
# feature extraction: 3283913180_7d4e43602d.jpg
# feature extraction: 3296150666_aae2f64348.jpg
# feature extraction: 326585030_e1dcca2562.jpg
# feature extraction: 3293642024_e136b74a55.jpg
# feature extraction: 3301021288_95935b7a74.jpg
# feature extraction: 3286822339_5535af6b93.jpg
# feature extraction: 3274879561_74997bbfff.jpg
# feature extraction: 3293945284_6a04e477a9.jpg
# feature extraction: 3292277400_f95cdd13d1.jpg
# feature extraction: 327621377_0bc3b7fd26.jpg
# feature extraction: 3264464625_c711cc40c6.jpg
# feature extraction: 3281078518_630a7a7f4f.jpg
# feature extraction: 3301935788_2bb7bbc515.jpg
# feature extraction: 3309578722_1765d7d1af.jpg
# feature extraction: 3303787342_b258b377b6.jpg
# feature extraction: 3270273940_61ef506f05.jpg
# feature extraction: 3265162450_5b4e3c5f1b.jpg
# feature extraction: 3264678536_46601d25f0.jpg
# feature extraction: 3288174272_2daa06d360.jpg
# feature extraction: 3286543624_7a327f79ae.jpg
# feature extraction: 3299820401_c2589186c5.jpg
# feature extraction: 3301438465_10121a2412.jpg
# feature extraction: 3278811919_d5a3432af6.jpg
# feature extraction: 3282434895_1c1efc1475.jpg
# feature extraction: 3308171165_20f93d2fba.jpg
# feature extraction: 3270691950_88583c3524.jpg
# feature extraction: 3273969811_42e9fa8f63.jpg
# feature extraction: 3265527323_6431f00692.jpg
# feature extraction: 3268908792_c24529fe88.jpg
# feature extraction: 3273489163_8209545810.jpg
# feature extraction: 3293596075_973b0bfd08.jpg
# feature extraction: 3299418821_21531b5b3c.jpg
# feature extraction: 3280052365_c4644bf0a5.jpg
# feature extraction: 3273091032_98f724b36b.jpg
# feature extraction: 3308488725_f91d9aba27.jpg
# feature extraction: 3294952558_96bb8c8cf3.jpg
# feature extraction: 3305895920_100a67d148.jpg
# feature extraction: 3279228339_71deaa3d9b.jpg
# feature extraction: 3275627207_0b41e44597.jpg
# feature extraction: 3286017638_c688c83e3d.jpg
# feature extraction: 3300679815_2c6c2301cb.jpg
# feature extraction: 3265964840_5374ed9c53.jpg
# feature extraction: 3301744710_b51280eb56.jpg
# feature extraction: 3295024992_887a95c700.jpg
# feature extraction: 3266399073_40820596d5.jpg
# feature extraction: 3264350290_f50494e835.jpg
# feature extraction: 3269380710_9161b0bd00.jpg
# feature extraction: 3295452057_0c987f895f.jpg
# feature extraction: 3275065565_9e2a640fbc.jpg
# feature extraction: 3272002857_ace031f564.jpg
# feature extraction: 3307563498_e2b4f19272.jpg
# feature extraction: 328916930_e4d4be1730.jpg
# feature extraction: 3275537015_74e04c0f3e.jpg
# feature extraction: 3289433994_4c67aab384.jpg
# feature extraction: 3273625566_2454f1556b.jpg
# feature extraction: 3282925526_535ff9f2b2.jpg
# feature extraction: 3307147971_5b3abf61f9.jpg
# feature extraction: 3271495320_bca47795fb.jpg
# feature extraction: 3276895962_c053263d01.jpg
# feature extraction: 3280672302_2967177653.jpg
# feature extraction: 3272071680_648a99f7d2.jpg
# feature extraction: 3282897060_8c584e2ce8.jpg
# feature extraction: 3286761458_34af7e4499.jpg
# feature extraction: 3283897411_af9d0b497d.jpg
# feature extraction: 3298175192_bbef524ddc.jpg
# feature extraction: 3294209955_a1f1e2cc19.jpg
# feature extraction: 3265864834_e0229020dd.jpg
# feature extraction: 3271385712_ffd34f2de5.jpg
# feature extraction: 3273163189_dece7babf4.jpg
# feature extraction: 3280173193_98c2d6a223.jpg
# feature extraction: 3286620180_4b00e93e8e.jpg
# feature extraction: 330325191_63e11d9c93.jpg
# feature extraction: 3294179574_4f67e67d6f.jpg
# feature extraction: 3292016893_24d14c8b4f.jpg
# feature extraction: 3275704430_a75828048f.jpg
# feature extraction: 327415627_6313d32a64.jpg
# feature extraction: 3274375509_4fe91a94c0.jpg
# feature extraction: 3278777548_290b881018.jpg
# feature extraction: 3271468462_701eb88d3b.jpg
# feature extraction: 3288274849_07ff76ee93.jpg
# feature extraction: 3282121432_648dac8a29.jpg
# feature extraction: 3291587911_81fc33300e.jpg
# feature extraction: 3308997740_91765ecdcc.jpg
# feature extraction: 3304030264_da3dd18c7b.jpg
# feature extraction: 3285214689_f0219e9671.jpg
# feature extraction: 3264650118_be7df266e7.jpg
# feature extraction: 3271178748_630d269811.jpg
# feature extraction: 3302804312_0272091cd5.jpg
# feature extraction: 3296124052_6f1d1c9f8d.jpg
# feature extraction: 326334188_8850b7bfd4.jpg
# feature extraction: 3289893683_d4cc3ce208.jpg
# feature extraction: 3276475986_66cd9cc7e4.jpg
# feature extraction: 3275711232_e261143664.jpg
# feature extraction: 3287969199_08e775d896.jpg
# feature extraction: 3268175963_113d90d178.jpg
# feature extraction: 3297272270_285b8878b2.jpg
# feature extraction: 3295671644_0e10891b6d.jpg
# feature extraction: 3263395801_5e4cee2b9e.jpg
# feature extraction: 3279524184_d5e2ffbaed.jpg
# feature extraction: 3276448136_0d9f5069c5.jpg
# feature extraction: 3263215700_e27f81f8b9.jpg
# feature extraction: 3269661567_faf190885a.jpg
# feature extraction: 3320756943_9d004f9824.jpg
# feature extraction: 3352531708_a65dd694b1.jpg
# feature extraction: 3346614841_698f9aa486.jpg
# feature extraction: 3349309109_4024a09a17.jpg
# feature extraction: 3339319023_5dcc3ef81a.jpg
# feature extraction: 3320411267_df70b90501.jpg
# feature extraction: 3337046794_296bd2c7e0.jpg
# feature extraction: 3351493005_6e5030f596.jpg
# feature extraction: 3326376344_3306bf439e.jpg
# feature extraction: 3333921867_6cc7d7c73d.jpg
# feature extraction: 3319338707_892ae2a660.jpg
# feature extraction: 3323988406_e3c8fce690.jpg
# feature extraction: 3326086533_23a0a54a8e.jpg
# feature extraction: 3347798761_5c5260b000.jpg
# feature extraction: 3315616181_15dd137e27.jpg
# feature extraction: 3327563443_870a33f748.jpg
# feature extraction: 3335547029_74d620fa6c.jpg
# feature extraction: 3317145805_071b15debb.jpg
# feature extraction: 3352199368_b35f25793e.jpg
# feature extraction: 3326454455_960e5442e9.jpg
# feature extraction: 3346289227_198fced308.jpg
# feature extraction: 3326588088_172d1b2584.jpg
# feature extraction: 3319388517_5609ae9805.jpg
# feature extraction: 3333039854_461329aac2.jpg
# feature extraction: 3316725440_9ccd9b5417.jpg
# feature extraction: 3348811097_0e09baa26f.jpg
# feature extraction: 3356284586_21c6f155a5.jpg
# feature extraction: 3313620862_0c65c645f5.jpg
# feature extraction: 3339768802_8ab768558a.jpg
# feature extraction: 3314180199_2121e80368.jpg
# feature extraction: 3324746155_71e14f60ce.jpg
# feature extraction: 3320356356_1497e53f80.jpg
# feature extraction: 3352697012_751b079bbb.jpg
# feature extraction: 3349451628_4249a21c8f.jpg
# feature extraction: 3336759846_5220e27deb.jpg
# feature extraction: 3323952123_deb50b0629.jpg
# feature extraction: 3321334180_8f764e0e0f.jpg
# feature extraction: 3316046339_8e504be038.jpg
# feature extraction: 3329858093_0ec73f2190.jpg
# feature extraction: 3315033940_e91f87b7f2.jpg
# feature extraction: 3331009729_d3b14738e6.jpg
# feature extraction: 3335501468_628655d608.jpg
# feature extraction: 3341489212_a879e1544a.jpg
# feature extraction: 3319899418_4bcf1b00d8.jpg
# feature extraction: 3325157569_8084ab3293.jpg
# feature extraction: 3349307529_c1a516b9dc.jpg
# feature extraction: 3354474353_daf9e168cf.jpg
# feature extraction: 3343311201_eeb1a39def.jpg
# feature extraction: 3348785391_c243faf6bb.jpg
# feature extraction: 3333675897_0043f992d3.jpg
# feature extraction: 3323498985_fd9d2803fd.jpg
# feature extraction: 3344632789_af90d54746.jpg
# feature extraction: 3353328134_dd9ed0edab.jpg
# feature extraction: 3347500603_13670ee6bf.jpg
# feature extraction: 3315726723_64c9b0a945.jpg
# feature extraction: 3318995586_c2bc50b92e.jpg
# feature extraction: 3327487011_1372c425fb.jpg
# feature extraction: 3323514651_3efdbd63ed.jpg
# feature extraction: 3322200641_c2e51ff37b.jpg
# feature extraction: 3349528565_0bc013b70a.jpg
# feature extraction: 3354883962_170d19bfe4.jpg
# feature extraction: 3330654550_3efe9a71af.jpg
# feature extraction: 3342271377_446ffc34c0.jpg
# feature extraction: 3323528927_7b21081271.jpg
# feature extraction: 3324375078_9441f72898.jpg
# feature extraction: 3325129757_7a1979ac11.jpg
# feature extraction: 3336065481_2c21e622c8.jpg
# feature extraction: 3351596152_bf283f03d1.jpg
# feature extraction: 3342822192_082f932ef2.jpg
# feature extraction: 3331525712_af1dcc47f2.jpg
# feature extraction: 3350785999_462f333c44.jpg
# feature extraction: 3325497914_f9014d615b.jpg
# feature extraction: 3335692531_dd4a995f91.jpg
# feature extraction: 3330935489_9cb67ca36b.jpg
# feature extraction: 3320032226_63390d74a6.jpg
# feature extraction: 3351360323_91bb341350.jpg
# feature extraction: 3321516504_5ee97771cb.jpg
# feature extraction: 3346711367_5e7b29e20f.jpg
# feature extraction: 3322443827_a04a94bb91.jpg
# feature extraction: 3336211088_4c294a870b.jpg
# feature extraction: 3312096605_f458757418.jpg
# feature extraction: 3349258288_5300c40430.jpg
# feature extraction: 3337461409_e4e317853d.jpg
# feature extraction: 3334537556_a2cf4e9b9a.jpg
# feature extraction: 3325910784_5ecb88310c.jpg
# feature extraction: 3356369156_074750c6cc.jpg
# feature extraction: 3318564834_4ccea90497.jpg
# feature extraction: 3354063643_1d8814eb13.jpg
# feature extraction: 3329169877_175cb16845.jpg
# feature extraction: 2856252334_1b1a230e70.jpg
# feature extraction: 286660725_ffdbdf3481.jpg
# feature extraction: 2873431806_86a56cdae8.jpg
# feature extraction: 2873065944_29c01782e2.jpg
# feature extraction: 2865564810_5c63328cd4.jpg
# feature extraction: 2831313661_1a328acb70.jpg
# feature extraction: 2856699493_65edef80a1.jpg
# feature extraction: 2836553263_b1a08c25ea.jpg
# feature extraction: 2891162278_fbf96be4f4.jpg
# feature extraction: 2837808847_5407af1986.jpg
# feature extraction: 2847859796_4d9cb0d31f.jpg
# feature extraction: 2875658507_c0d9ceae90.jpg
# feature extraction: 2876848241_63290edfb4.jpg
# feature extraction: 2872963574_52ab5182cb.jpg
# feature extraction: 288508162_1727873924.jpg
# feature extraction: 2842865689_e37256d9ce.jpg
# feature extraction: 2856524322_1d04452a21.jpg
# feature extraction: 2884400562_e0851014fc.jpg
# feature extraction: 2856456013_335297f587.jpg
# feature extraction: 2855594918_1d1e6a6061.jpg
# feature extraction: 2863027424_9c75105660.jpg
# feature extraction: 2831672255_d779807c14.jpg
# feature extraction: 2831723637_30d4456665.jpg
# feature extraction: 2881441125_b580e3dd4b.jpg
# feature extraction: 2851931813_eaf8ed7be3.jpg
# feature extraction: 2860202109_97b2b22652.jpg
# feature extraction: 2868324804_5cc8030484.jpg
# feature extraction: 2845691057_d4ab89d889.jpg
# feature extraction: 2853205396_4fbe8d7a73.jpg
# feature extraction: 2866093652_aa717eb9ce.jpg
# feature extraction: 2883907436_82bf4a36b8.jpg
# feature extraction: 2866254827_9a8f592017.jpg
# feature extraction: 288025239_5e59ba9c3b.jpg
# feature extraction: 2870426310_4d59795032.jpg
# feature extraction: 2867026654_38be983b44.jpg
# feature extraction: 288177922_b889f2e1fe.jpg
# feature extraction: 2831656774_36982aafdb.jpg
# feature extraction: 2877424957_9beb1dc49a.jpg
# feature extraction: 2824004868_1fc0a81173.jpg
# feature extraction: 2866529477_7e0c053ebc.jpg
# feature extraction: 2873837796_543e415e98.jpg
# feature extraction: 2873522522_829ea62491.jpg
# feature extraction: 2839532455_36a7dc4758.jpg
# feature extraction: 2845246160_d0d1bbd6f0.jpg
# feature extraction: 2872806249_00bea3c4e7.jpg
# feature extraction: 2826647354_650ff5eb03.jpg
# feature extraction: 2885387575_9127ea10f1.jpg
# feature extraction: 2887798667_ce761d45e8.jpg
# feature extraction: 2837799692_2f1c50722a.jpg
# feature extraction: 2862004252_53894bb28b.jpg
# feature extraction: 2825668136_107223182c.jpg
# feature extraction: 2861100960_457ceda7fa.jpg
# feature extraction: 2846785268_904c5fcf9f.jpg
# feature extraction: 2839890871_4b7c7dbd96.jpg
# feature extraction: 2867736861_43c9487a65.jpg
# feature extraction: 2854291706_d4c31dbf56.jpg
# feature extraction: 2871962580_b85ce502ba.jpg
# feature extraction: 2825540754_5e0c13e6b8.jpg
# feature extraction: 2885382946_f541ea5722.jpg
# feature extraction: 2831578193_3c997ae330.jpg
# feature extraction: 2826030193_4278ccb833.jpg
# feature extraction: 2846843520_b0e6211478.jpg
# feature extraction: 2857609295_16aaa85293.jpg
# feature extraction: 2850719435_221f15e951.jpg
# feature extraction: 2844963839_ff09cdb81f.jpg
# feature extraction: 2874728371_ccd6db87f3.jpg
# feature extraction: 2860040276_eac0aca4fc.jpg
# feature extraction: 2881087519_ca0aa79b2b.jpg
# feature extraction: 2836360729_6500249fe6.jpg
# feature extraction: 2846037553_1a1de50709.jpg
# feature extraction: 2838085973_42b6e9b5b1.jpg
# feature extraction: 2891185857_54942809cf.jpg
# feature extraction: 2887614578_ed7ba21775.jpg
# feature extraction: 2833582518_074bef3ed6.jpg
# feature extraction: 2857558098_98e9249284.jpg
# feature extraction: 2852982055_8112d0964f.jpg
# feature extraction: 2836703077_fa9c736203.jpg
# feature extraction: 2870875612_2cbb9e4a3c.jpg
# feature extraction: 2867968184_908d87cf2c.jpg
# feature extraction: 2856700531_312528eea4.jpg
# feature extraction: 2882743431_c3e6cd1b5c.jpg
# feature extraction: 2891240104_6755281868.jpg
# feature extraction: 2837908308_8bc25c6b02.jpg
# feature extraction: 2862676319_a9dab1309f.jpg
# feature extraction: 2862469183_a4334b904a.jpg
# feature extraction: 2882893687_1d10d68f2b.jpg
# feature extraction: 2831846986_5534425cfa.jpg
# feature extraction: 2886533440_dfa832f2fa.jpg
# feature extraction: 2853811730_fbb8ab0878.jpg
# feature extraction: 2830755303_2b5444ab4c.jpg
# feature extraction: 2873648844_8efc7d78f1.jpg
# feature extraction: 2877088081_7ca408cb25.jpg
# feature extraction: 2838619742_eed855d8a8.jpg
# feature extraction: 2861413434_f0e2a10179.jpg
# feature extraction: 2887750774_920eb171aa.jpg
# feature extraction: 2890057168_c712f932e0.jpg
# feature extraction: 2876993733_cb26107d18.jpg
# feature extraction: 2866974237_e3c1e267c0.jpg
# feature extraction: 2878705136_609dfbf318.jpg
# feature extraction: 2877511986_c965ced502.jpg
# feature extraction: 2862509442_4f5dc96dca.jpg
# feature extraction: 2884651479_12e400ee58.jpg
# feature extraction: 2857473929_4f52662c30.jpg
# feature extraction: 2854207034_1f00555703.jpg
# feature extraction: 2866686547_0a67eb899d.jpg
# feature extraction: 2833431496_09d999db4d.jpg
# feature extraction: 2836325261_a3bf5c59be.jpg
# feature extraction: 2860400846_2c1026a573.jpg
# feature extraction: 2845845721_d0bc113ff7.jpg
# feature extraction: 2891617125_f939f604c7.jpg
# feature extraction: 2830880811_d7f66dd2cf.jpg
# feature extraction: 2870194345_0bcbac1aa5.jpg
# feature extraction: 2823200990_7b02b7cc36.jpg
# feature extraction: 2886411666_72d8b12ce4.jpg
# feature extraction: 285306009_f6ddabe687.jpg
# feature extraction: 2869253972_aa72df6bf3.jpg
# feature extraction: 2875583266_4da13ae12d.jpg
# feature extraction: 2848571082_26454cb981.jpg
# feature extraction: 2860372882_e0ef4131d4.jpg
# feature extraction: 2855417531_521bf47b50.jpg
# feature extraction: 2844846111_8c1cbfc75d.jpg
# feature extraction: 2874984466_1aafec2c9f.jpg
# feature extraction: 2864340145_d28b842faf.jpg
# feature extraction: 284441196_8ebb216d0d.jpg
# feature extraction: 2864634088_d087494dff.jpg
# feature extraction: 2885891981_6b02620ae9.jpg
# feature extraction: 2862481071_86c65d46fa.jpg
# feature extraction: 2848977044_446a31d86e.jpg
# feature extraction: 2874876837_80d178ba9b.jpg
# feature extraction: 2841449931_84a05850ec.jpg
# feature extraction: 2884252132_5d8e776893.jpg
# feature extraction: 2888702775_0939a6680e.jpg
# feature extraction: 2863848437_f2592ab42d.jpg
# ...
# feature extraction: 1584315962_5b0b45d02d.jpg
# feature extraction: 2043427251_83b746da8e.jpg
# feature extraction: 2029280005_a19609c81a.jpg
# feature extraction: 1770036088_08abe4f6e9.jpg
# feature extraction: 1606988704_fe330878a3.jpg
# feature extraction: 180506881_de0f59770f.jpg
# feature extraction: 160792599_6a7ec52516.jpg
# feature extraction: 179829865_095b040377.jpg
# feature extraction: 2058091220_2087270068.jpg
# feature extraction: 1798209205_77dbf525b0.jpg
# feature extraction: 1581822598_0ae23074f1.jpg
# feature extraction: 2059616165_b7c99c1009.jpg
# feature extraction: 2045562030_654ddea5e5.jpg
# feature extraction: 2049646140_d0de01e3c4.jpg
# feature extraction: 1540631615_8b42c1b160.jpg
# feature extraction: 1676601498_7d59327523.jpg
# feature extraction: 1731546544_9fbf14617b.jpg
# feature extraction: 2064790732_219e52e19c.jpg
# feature extraction: 1550772959_9ca9fa625f.jpg
# feature extraction: 191003284_1025b0fb7d.jpg
# feature extraction: 181157221_e12410ef0b.jpg
# feature extraction: 159712188_d530dd478c.jpg
# feature extraction: 1547883892_e29b3db42e.jpg
# feature extraction: 1808504612_3508f3c9bb.jpg
# feature extraction: 1956678973_223cb1b847.jpg
# feature extraction: 1579198375_84b18e003a.jpg
# feature extraction: 1679565118_d36f0d6d52.jpg
# feature extraction: 181415975_2627aa6668.jpg
# feature extraction: 180094434_b0f244832d.jpg
# feature extraction: 174466741_329a52b2fe.jpg
# feature extraction: 1732217138_aa0199ef87.jpg
# feature extraction: 1937262236_cbf5bfa101.jpg
# feature extraction: 2039457436_fc30f5e1ce.jpg
# feature extraction: 1763020597_d4cc8f0f8a.jpg
# feature extraction: 2058472558_7dd5014abd.jpg
# feature extraction: 1806580620_a8fe0fb9f8.jpg
# feature extraction: 1962729184_6996e128e7.jpg
# feature extraction: 1626754053_81126b67b6.jpg
# feature extraction: 1574401950_6bedc0d29b.jpg
# feature extraction: 154871781_ae77696b77.jpg
# feature extraction: 1557838421_a33f2a4911.jpg
# feature extraction: 161669933_3e7d8c7e2c.jpg
# feature extraction: 1682079482_9a72fa57fa.jpg
# feature extraction: 1691573772_1adef8e40e.jpg
# feature extraction: 195084264_72fb347b0f.jpg
# feature extraction: 1670592963_39731a3dac.jpg
# feature extraction: 195962284_e57178054a.jpg
# feature extraction: 1679557684_50a206e4a9.jpg
# feature extraction: 199463720_329a802206.jpg
# feature extraction: 1957371533_62bc720bac.jpg
# feature extraction: 2056930414_d2b0f1395a.jpg
# feature extraction: 1542033433_5453d4c466.jpg
# feature extraction: 203114209_e4cd71a6b7.jpg
# feature extraction: 167295035_336f5f5f27.jpg
# feature extraction: 1713248099_d860df4e10.jpg
# feature extraction: 1859726819_9a793b3b44.jpg
# feature extraction: 2063277300_f7ff476914.jpg
# feature extraction: 1984936420_3f3102132b.jpg
# feature extraction: 1876536922_8fdf8d7028.jpg
# feature extraction: 162743064_bb242faa31.jpg
# feature extraction: 1881494074_1bebd93089.jpg
# feature extraction: 1541272333_1624b22546.jpg
# feature extraction: 1813597483_3f09d2a020.jpg
# feature extraction: 1773928579_5664a810dc.jpg
# feature extraction: 2092177624_13ab757e8b.jpg
# feature extraction: 2157003092_eaeb977789.jpg
# feature extraction: 2088910854_c6f8d4f5f9.jpg
# feature extraction: 2159447283_fab8c272b0.jpg
# feature extraction: 2097403787_77a154f5b9.jpg
# feature extraction: 2190227737_6e0bde2623.jpg
# feature extraction: 2102030040_2e8f4738f7.jpg
# feature extraction: 2178064851_bb39652d28.jpg
# feature extraction: 2186139563_e60c1d4b8b.jpg
# feature extraction: 2185793891_5a5e903ca6.jpg
# feature extraction: 2169067981_cc19268f23.jpg
# feature extraction: 2193980605_4221c6474d.jpg
# feature extraction: 2156131463_5b53636cf0.jpg
# feature extraction: 2200901777_f6c168bd32.jpg
# feature extraction: 2069279767_fb32bfb2de.jpg
# feature extraction: 2065309381_705b774f51.jpg
# feature extraction: 2089442007_6fc798548c.jpg
# feature extraction: 2140182410_8e2a06fbda.jpg
# feature extraction: 2148695079_9ae6a9b1c7.jpg
# feature extraction: 2079110798_ad1370a646.jpg
# feature extraction: 2085726719_a57a75dbe5.jpg
# feature extraction: 2204277704_f1c8c741ed.jpg
# feature extraction: 2065875490_a46b58c12b.jpg
# feature extraction: 2114355355_9d7e2d8178.jpg
# feature extraction: 2067833088_04e84e5bf2.jpg
# feature extraction: 2196846255_2c1635359a.jpg
# feature extraction: 2103568100_5d018c495b.jpg
# feature extraction: 2109479807_eec8d72ca7.jpg
# feature extraction: 2100735137_05c6079537.jpg
# feature extraction: 2097420505_439f63c863.jpg
# feature extraction: 2116444946_1f5d1fe5d1.jpg
# feature extraction: 218342358_1755a9cce1.jpg
# feature extraction: 2099323664_bb20457f26.jpg
# feature extraction: 2149982207_5345633bbf.jpg
# feature extraction: 2088120475_d6318364f5.jpg
# feature extraction: 2158267555_db1d94e468.jpg
# feature extraction: 2091171488_c8512fec76.jpg
# feature extraction: 2197275664_fabcf3424b.jpg
# feature extraction: 2085255128_61224cc47f.jpg
# feature extraction: 2151056407_c9c09b0a02.jpg
# feature extraction: 2113530024_5bc6a90e42.jpg
# feature extraction: 2172526745_649f420569.jpg
# feature extraction: 2192333873_2a0cbe849d.jpg
# feature extraction: 2187503678_fd743e0a00.jpg
# feature extraction: 2111360187_d2505437b7.jpg
# feature extraction: 2101128963_fdf8b2a0d7.jpg
# feature extraction: 2102360862_264452db8e.jpg
# feature extraction: 2189995738_352607a63b.jpg
# feature extraction: 2204777844_1bcf26bf84.jpg
# feature extraction: 2074764331_90a9962b52.jpg
# feature extraction: 207930963_af3a2f1784.jpg
# feature extraction: 2120383553_5825333a3f.jpg
# feature extraction: 2203449950_e51d0f9065.jpg
# feature extraction: 211295363_49010ca38d.jpg
# feature extraction: 2112921744_92bf706805.jpg
# feature extraction: 2181846120_3744ca3942.jpg
# feature extraction: 2119660490_ce0d4d1f73.jpg
# feature extraction: 2189181027_a445b13438.jpg
# feature extraction: 2178095150_436b035741.jpg
# feature extraction: 2105756457_a100d8434e.jpg
# feature extraction: 2125216241_5b265a2fbc.jpg
# feature extraction: 2201951969_0d7520d648.jpg
# feature extraction: 2129430111_338a94f8fb.jpg
# feature extraction: 2098174172_e57d86ea03.jpg
# feature extraction: 2165459064_5b81ff23eb.jpg
# feature extraction: 2090339522_d30d2436f9.jpg
# feature extraction: 2174206711_11cb712a8d.jpg
# feature extraction: 2090997177_76d482b158.jpg
# feature extraction: 2124040721_bffc0a091a.jpg
# feature extraction: 2087317114_cf06df5aa5.jpg
# feature extraction: 2140747429_62cfd89ae9.jpg
# feature extraction: 2086513494_dbbcb583e7.jpg
# feature extraction: 2195887578_3ba2f29b48.jpg
# feature extraction: 2095007523_591f255708.jpg
# feature extraction: 2199083344_3aa77f4879.jpg
# feature extraction: 2128119486_4407061c40.jpg
# feature extraction: 2171576939_d1e72daab2.jpg
# feature extraction: 2103361407_4ed4fc46bf.jpg
# feature extraction: 2089426086_7acc98a3a8.jpg
# feature extraction: 2100909581_b7dde5b704.jpg
# feature extraction: 2085557551_7a88d01d4e.jpg
# feature extraction: 2196284168_76417efbec.jpg
# feature extraction: 2085403342_a17b0654fe.jpg
# feature extraction: 2186087673_c7a73da7ce.jpg
# feature extraction: 2136514643_93d8f75a77.jpg
# feature extraction: 2121357310_f8235311da.jpg
# feature extraction: 2102315758_a9148a842f.jpg
# feature extraction: 2136992638_098d62a3c5.jpg
# feature extraction: 2066271441_1f1f056c01.jpg
# feature extraction: 2115620856_4fa5025ac6.jpg
# feature extraction: 2130851544_d36f4f2ea6.jpg
# feature extraction: 2107837987_ffecfc367a.jpg
# feature extraction: 2196316998_3b2d63f01f.jpg
# feature extraction: 2097398349_ff178b3f1b.jpg
# feature extraction: 2161799386_27aa938421.jpg
# feature extraction: 2120571547_05cd56de85.jpg
# feature extraction: 2188192752_09d9fc5431.jpg
# feature extraction: 2150564996_d173a506d7.jpg
# feature extraction: 2203615439_3c7cdc39dc.jpg
# feature extraction: 2079152458_40712c3b40.jpg
# feature extraction: 2081615901_13092cac56.jpg
# feature extraction: 2101457132_69c950bc45.jpg
# feature extraction: 2176364472_31fcd37531.jpg
# feature extraction: 2139519215_8ca16dd192.jpg
# feature extraction: 2089555297_95cf001fa7.jpg
# feature extraction: 2135360514_7dcb9ed796.jpg
# feature extraction: 2116316160_d5fa7abdc3.jpg
# feature extraction: 2119302248_72493d458c.jpg
# feature extraction: 2077346067_0a3a5aae65.jpg
# feature extraction: 2137071442_1c9658c81a.jpg
# feature extraction: 2127209046_94711c747b.jpg
# feature extraction: 2187720319_112d00f07d.jpg
# feature extraction: 2192131110_8a40e7c028.jpg
# feature extraction: 2094810449_f8df9dcdf7.jpg
# feature extraction: 2106772874_381824648b.jpg
# feature extraction: 2156726763_034ecd2e39.jpg
# feature extraction: 2193223202_4d908c0450.jpg
# feature extraction: 216172386_9ac5356dae.jpg
# feature extraction: 2084217208_7bd9bc85e5.jpg
# feature extraction: 2096771662_984441d20d.jpg
# feature extraction: 2081141788_38fa84ce3c.jpg
# feature extraction: 2182488373_df73c7cc09.jpg
# feature extraction: 207237775_fa0a15c6fe.jpg
# feature extraction: 2067362863_59577f9d4d.jpg
# feature extraction: 2109911919_af45b93ef3.jpg
# feature extraction: 2064792226_97e41d8167.jpg
# feature extraction: 2171891283_dedd9cf416.jpg
# feature extraction: 211981411_e88b8043c2.jpg
# feature extraction: 2090387793_274ab4cf7d.jpg
# feature extraction: 2114739371_83aa8bdb0e.jpg
# feature extraction: 211277478_7d43aaee09.jpg
# feature extraction: 2130986011_47cb05c8c9.jpg
# feature extraction: 2084103826_ffd76b1e3e.jpg
# feature extraction: 2201222219_8d656b0633.jpg
# feature extraction: 2181117039_c4eea8036e.jpg
# feature extraction: 2087640654_1a84577a44.jpg
# feature extraction: 207731022_988f6afb35.jpg
# feature extraction: 2120411340_104eb610b1.jpg
# feature extraction: 2109370875_05241bdda7.jpg
# feature extraction: 214501174_6db1f4d69c.jpg
# feature extraction: 2073964624_52da3a0fc4.jpg
# feature extraction: 209605542_ca9cc52e7b.jpg
# feature extraction: 2100046085_69b59b6645.jpg
# feature extraction: 210625425_fb1ef5d23b.jpg
# feature extraction: 2068403258_2669cf9763.jpg
# feature extraction: 2095435987_1b7591d214.jpg
# feature extraction: 2181724497_dbb7fcb0a9.jpg
# feature extraction: 2073174497_18b779999c.jpg
# feature extraction: 210839948_bbd5bfa3b6.jpg
# feature extraction: 2083778090_3aecaa11cc.jpg
# feature extraction: 2097407245_c798e0dcaf.jpg
# feature extraction: 2170222061_e8bce4a32d.jpg
# feature extraction: 2201978994_c444e64810.jpg
# feature extraction: 2107838729_a527e434bd.jpg
# feature extraction: 2090386465_b6ebb7df2c.jpg
# feature extraction: 2081446176_f97dc76951.jpg
# feature extraction: 2123932281_1a4fd38455.jpg
# feature extraction: 2138487671_5b89104043.jpg
# feature extraction: 213216174_0632af65a2.jpg
# feature extraction: 2204695848_3d1b140212.jpg
# feature extraction: 2101808682_0d66ef4a08.jpg
# feature extraction: 2086678529_b3301c2d71.jpg
# feature extraction: 2201192417_d934730fea.jpg
# feature extraction: 2173677067_9d0732bcc2.jpg
# feature extraction: 2198511848_311d8a8c2f.jpg
# feature extraction: 2176874361_2b4149010b.jpg
# feature extraction: 2182050469_1edac0bc60.jpg
# feature extraction: 2149968397_a7411729d1.jpg
# feature extraction: 2195419145_36722e8d54.jpg
# feature extraction: 2078311270_f01c9eaf4c.jpg
# feature extraction: 215876547_fa584c5ec3.jpg
# feature extraction: 2170187328_65c2f11891.jpg
# feature extraction: 2079554580_f18d5c181b.jpg
# feature extraction: 2066048248_f53f5ef5e2.jpg
# feature extraction: 2121140070_a09644550b.jpg
# feature extraction: 2108799322_e25aa6e185.jpg
# feature extraction: 2070831281_dc04b3e15d.jpg
# feature extraction: 2192411521_9c7e488c5e.jpg
# feature extraction: 2074146683_7c83167aa1.jpg
# feature extraction: 2092419948_eea8001d0f.jpg
# feature extraction: 2131762850_5293a288d9.jpg
# feature extraction: 219070971_ae43410b9e.jpg
# feature extraction: 2151300603_248a9fe715.jpg
# feature extraction: 2199200615_85e4c2a602.jpg
# feature extraction: 2125454445_5c5c4bf906.jpg
# feature extraction: 2171154778_8189169336.jpg
# feature extraction: 2198484810_50a893824a.jpg
# feature extraction: 2205328215_3ffc094cde.jpg
# feature extraction: 219843860_332e5ca7d4.jpg
# feature extraction: 2180886307_5156460b2c.jpg
# feature extraction: 2194286203_5dc620006a.jpg
# feature extraction: 2195620255_6693479734.jpg
# feature extraction: 207584893_63e73c5c28.jpg
# feature extraction: 2164363131_6930455d45.jpg
# feature extraction: 1130401779_8c30182e3e.jpg
# feature extraction: 1213336750_2269b51397.jpg
# feature extraction: 114051287_dd85625a04.jpg
# feature extraction: 1295669416_21cabf594d.jpg
# feature extraction: 1282392036_5a0328eb86.jpg
# feature extraction: 1176580356_9810d877bf.jpg
# feature extraction: 1003163366_44323f5815.jpg
# feature extraction: 1129704496_4a61441f2c.jpg
# feature extraction: 1132772170_600610c5df.jpg
# feature extraction: 109823395_6fb423a90f.jpg
# feature extraction: 109671650_f7bbc297fa.jpg
# feature extraction: 118309463_a532b75be9.jpg
# feature extraction: 119534510_d52b3781a3.jpg
# feature extraction: 1240297429_c36ae0c58f.jpg
# feature extraction: 1075716537_62105738b4.jpg
# feature extraction: 1267711451_e2a754b4f8.jpg
# feature extraction: 1167662968_e466f1e80a.jpg
# feature extraction: 1119463452_69d4eecd08.jpg
# feature extraction: 1287920676_d21a0b289b.jpg
# feature extraction: 1280147517_98767ca3b3.jpg
# feature extraction: 1057089366_ca83da0877.jpg
# feature extraction: 1244485675_822e6efe60.jpg
# feature extraction: 1055753357_4fa3d8d693.jpg
# feature extraction: 1222322358_225067636e.jpg
# feature extraction: 1096395242_fc69f0ae5a.jpg
# feature extraction: 1075867198_27ca2e7efe.jpg
# feature extraction: 116409198_0fe0c94f3b.jpg
# feature extraction: 124195430_d14028660f.jpg
# feature extraction: 1082379191_ec1e53f996.jpg
# feature extraction: 109738916_236dc456ac.jpg
# feature extraction: 1007129816_e794419615.jpg
# feature extraction: 1253275679_e955fb7304.jpg
# feature extraction: 1163282319_b729b24c46.jpg
# feature extraction: 1225443522_1633e7121f.jpg
# feature extraction: 1056359656_662cee0814.jpg
# feature extraction: 1022975728_75515238d8.jpg
# feature extraction: 109202756_b97fcdc62c.jpg
# feature extraction: 1117972841_2b9261f95f.jpg
# feature extraction: 1178705300_c224d9a4f1.jpg
# feature extraction: 1000268201_693b08cb0e.jpg
# feature extraction: 1088767354_2acee738cf.jpg
# feature extraction: 123997871_6a9ca987b1.jpg
# feature extraction: 106514190_bae200f463.jpg
# feature extraction: 1169307342_e7a4685a5c.jpg
# feature extraction: 111766423_4522d36e56.jpg
# feature extraction: 1131804997_177c3c0640.jpg
# feature extraction: 1119418776_58e4b93eac.jpg
# feature extraction: 1121416483_c7902d0d49.jpg
# feature extraction: 113678030_87a6a6e42e.jpg
# feature extraction: 1189977786_4f5aaed773.jpg
# feature extraction: 1197800988_7fb0ca4888.jpg
# feature extraction: 1260816604_570fc35836.jpg
# feature extraction: 1030985833_b0902ea560.jpg
# feature extraction: 1287931016_fb015e2e10.jpg
# feature extraction: 124881487_36e668145d.jpg
# feature extraction: 103205630_682ca7285b.jpg
# feature extraction: 1089755335_0bfbfd30e6.jpg
# feature extraction: 1142847777_2a0c1c2551.jpg
# feature extraction: 1247181182_35cabd76f3.jpg
# feature extraction: 1248734482_3038218f3b.jpg
# feature extraction: 1107471216_4336c9b328.jpg
# feature extraction: 1285874746_486731a954.jpg
# feature extraction: 1096165011_cc5eb16aa6.jpg
# feature extraction: 1160034462_16b38174fe.jpg
# feature extraction: 1295671216_cde1b9c9d1.jpg
# feature extraction: 1130369873_d80a1aa59c.jpg
# feature extraction: 112243673_fd68255217.jpg
# feature extraction: 1287982439_6578006e22.jpg
# feature extraction: 128912885_8350d277a4.jpg
# feature extraction: 1271210445_7f7ecf3791.jpg
# feature extraction: 1206506157_c7956accd5.jpg
# feature extraction: 1093737381_b313cd49ff.jpg
# feature extraction: 108898978_7713be88fc.jpg
# feature extraction: 1252787177_4b08625897.jpg
# feature extraction: 1232148178_4f45cc3284.jpg
# feature extraction: 1207159468_425b902bfb.jpg
# feature extraction: 1251558317_4ef844b775.jpg
# feature extraction: 1262077938_8b9516c273.jpg
# feature extraction: 1227655020_b11a1bb112.jpg
# feature extraction: 1032122270_ea6f0beedb.jpg
# feature extraction: 1289142574_2bd6a082dd.jpg
# feature extraction: 1298295313_db1f4c6522.jpg
# feature extraction: 124972799_de706b6d0b.jpg
# feature extraction: 1235681222_819231767a.jpg
# feature extraction: 1124448967_2221af8dc5.jpg
# feature extraction: 1287064529_aa4e4f3c31.jpg
# feature extraction: 1167908324_8caab45e15.jpg
# feature extraction: 1177994172_10d143cb8d.jpg
# feature extraction: 101654506_8eb26cfb60.jpg
# feature extraction: 105342180_4d4a40b47f.jpg
# feature extraction: 1019077836_6fc9b15408.jpg

# %%
def caption_dictionary(raw_caption):
    """
    Input: raw_caption as retrieved from the dataset
    Return: A dictionary mapping [photo_id] -> caption_list of that photo
    """
    captions = {}
    for line in raw_caption.split('\n'):
        if len(line) < 1:
            continue
        
        tmp = line.split()
        photo_id = tmp[0].split('.')[0] #id
        caption = ' '.join(tmp[1:])
        
        if photo_id not in captions.keys():
            captions[photo_id] = []
        captions[photo_id].append(caption) #A list of captions

    return(captions)

def cleaning(caption_dict):
    """
    Input: A dictionary of caption_list returned by caption_dictionary()
    Output: The cleaned caption dictionary
    """
    trans_table = str.maketrans('', '', string.punctuation)
    for photo_id, caption_list in caption_dict.items():
        for i in range(len(caption_list)):
            caption = caption_list[i]
            tmp = caption.split()
            
            tmp = [t.lower() for t in tmp] #Lower case
            tmp = [t.translate(trans_table) for t in tmp] #Remove punctuation
            tmp = [t for t in tmp if len(t) > 1] #Remove words with a single alphabet
            tmp = [t for t in tmp if t.isalpha()] #Remove words which contain non-alphabet
            
            caption_list[i] = ' '.join(tmp)

    return(None)


with open("/content/drive/My Drive/Flickr8k_text/Flickr8k.token.txt", "r") as f:
    raw_caption = f.read()
        
caption_dict = caption_dictionary(raw_caption)
cleaning(caption_dict)

# %%
def caption_to_list(caption_dict):
    #Return: a list of all captions from the caption_dict
    captions = []
    for caption_list in caption_dict.values():
        for c in caption_list:
            captions.append(c.split())
    return(captions)
    
def create_tokenizer(caption_dict, num_vocab=None):
    """
    Input: caption dictionary, num_vocab
    Output: Tokenizer fitted on the captions in the dictionary, with maximum number of vocab = num_vocab
    """
    tokenizer = keras.preprocessing.text.Tokenizer(num_words=num_vocab)
    captions = caption_to_list(caption_dict)
            
    tokenizer.fit_on_texts(captions)
    return(tokenizer)

def word2idx(word):
    """
    Input: word to encode
    Output: index of the word
    """
    return word_model.wv.key_to_index[word]

def idx2word(idx):
    """
    Input: index of the word to decode
    Output: word to decode
    """
    return word_model.wv.index_to_key[idx]

#Identify training / development / testing set
def dataset(filename):
    """
    Input: filename of dataset
    Output: A list of identifier in the dataset
    """
    dataset = []
    with open(filename, "r") as f:
        text = f.read()
    
    for line in text.split('\n'):
        if len(line) < 1:
            continue
        dataset.append(line.split('.')[0])
        
    return(dataset)

def load_features(dataset, features):
    """
    Input: dataset (list of identifier)
    Output: The VGG-16 features according to the identifiers
    """
    features = {photo_id: features[photo_id] for photo_id in dataset}
    
    return(features)
    
def load_captions(dataset, caption_dict, wrapping = 0):
    """
    Input: dataset (list of identifier), wrapping (by startseq / endseq)
    Output: The caption_dict according to the identifiers, with / without wrapping of (startseq, endseq)
    """
    caption_dict = {photo_id: caption_dict[photo_id] for photo_id in dataset}
    
    if wrapping:
        for photo_id, caption_list in caption_dict.items():
            for i in range(len(caption_list)):
                tmp = caption_list[i].split()
                caption_list[i] = 'startseq '+ ' '.join(tmp) + ' endseq'
    
    return(caption_dict)



train = dataset("/content/drive/My Drive/Flickr8k_text/Flickr_8k.trainImages.txt")
dev = dataset("/content/drive/My Drive/Flickr8k_text/Flickr_8k.devImages.txt")
test = dataset("/content/drive/My Drive/Flickr8k_text/Flickr_8k.testImages.txt")
    
train_caption_dict = load_captions(train,caption_dict, 1)
train_features = load_features(train, features)
dev_caption_dict = load_captions(dev,caption_dict, 1)
dev_features = load_features(dev, features)
test_caption_dict = load_captions(test,caption_dict, 0)
test_features = load_features(test, features)

#Train word2vec
sentences = [['padd'] + sentence for sentence in caption_to_list(train_caption_dict)]
word_model = gensim.models.Word2Vec(sentences=sentences, vector_size=100, min_count=2, window=5, epochs=100)
pretrained_weights = word_model.wv.vectors
vocab_size, emdedding_size = pretrained_weights.shape
    
max_length = max([len(c) for c in caption_to_list(train_caption_dict)]) - 1 #Maximum length of input sequence
print("max length: {}".format(max_length))
# Out:
# max length: 33

# %%
def define_model(max_length, vocab_size, embedding_size, pretrained_weights):
    img_inputs = keras.layers.Input(shape=(4096,))
    img_dp1 = keras.layers.Dropout(rate=0.2)(img_inputs)
    img_dense = keras.layers.Dense(128)(img_dp1)
    img_bn1 = keras.layers.BatchNormalization()(img_dense)
    img_outputs = keras.layers.Activation(activation='relu')(img_bn1)
    #RepeatVector for matching timestep
    img_rep = keras.layers.RepeatVector(n=max_length)(img_outputs)
    
    text_inputs = keras.layers.Input(shape=(max_length,))
    embedding = keras.layers.Embedding(input_dim=130, output_dim=100, mask_zero = True)
    mask = embedding.compute_mask(text_inputs)
    mask = tf.reshape(mask,[tf.shape(mask)[0],tf.shape(mask)[1],1])
    mask = tf.cast(mask,np.float32)
    text_embed = embedding(text_inputs)
    text_lstm = keras.layers.Bidirectional(keras.layers.LSTM(128), merge_mode = 'sum')(text_embed)

    #attention mechanism
    attention = keras.layers.Dense(1, activation='tanh')(text_lstm)
    attention = keras.layers.Flatten()(attention)
    attention = keras.layers.Activation('softmax')(attention)
    attention = keras.layers.RepeatVector(128)(attention)
    attention = keras.layers.Permute([2, 1])(attention)
    sent_representation = keras.layers.Multiply()([text_lstm, attention])
    
    decoder_inputs = keras.layers.Concatenate()([img_rep, text_lstm])
    decoder_dp1 = keras.layers.Dropout(rate=0.5, noise_shape=(None, 1, 256))(decoder_inputs)
    decoder_dense1 = keras.layers.Dense(256)(decoder_dp1)
    decoder_dp2 = keras.layers.Dropout(rate=0.5, noise_shape=(None, 1, 256))(decoder_dense1)
    decoder_relu1 = keras.layers.Activation(activation='relu')(decoder_dp2)
    decoder_outputs = keras.layers.Dense(vocab_size, activation='softmax')(decoder_relu1)
    decoder_outputs = keras.layers.Multiply()([decoder_outputs,mask])
    
    model = keras.models.Model(inputs = [img_inputs, text_inputs], outputs=decoder_outputs)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    print(model.summary())
    
    return(model)

"""
4. Progressive model training
"""

def generate_dataset(caption_dict, features, max_length, vocab_size, num_photos=32):
    """
    A generator of dataset for model training / validation.
    Input: train / val (caption_dict & features)
    Yield: a batch of [[X_img, X_text], Y] as the model input for model.fit_generator() / model.evaluate_generator()
    """
    
    #list of photo_ids
    photo_ids = list(caption_dict.keys())
    while 1:
        s = np.random.choice(np.arange(len(photo_ids)), size=len(photo_ids), replace=False)
        
        count = 0 #counter
        X_img = []
        X_text = []
        Y = []
        while 1:
            #sample the photo_id along the random sequence
            s1 = s[count]
            photo_id = photo_ids[s1]
            caption_list = caption_dict[photo_id]
            
            #sample the caption randomly
            s2 = np.random.choice(np.arange(len(caption_list)), size=1, replace=True)[0]
            caption = caption_list[s2].split()

            encoded = [word2idx(word) for word in caption if word in word_model.wv.key_to_index]
            
            tmp_text, tmp_Y = encoded[:-1], encoded[1:]
            padded_text = keras.preprocessing.sequence.pad_sequences([tmp_text], maxlen=max_length, padding='pre')[0]
            padded_Y = keras.preprocessing.sequence.pad_sequences([tmp_Y], maxlen=max_length, padding='pre')[0]
            padded_Y = keras.utils.np_utils.to_categorical(padded_Y, num_classes=vocab_size)
            
            X_img.append(features[photo_id][0])
            X_text.append(padded_text)
            Y.append(padded_Y)
            
            #Generate until: num_photos photos; iterate through all photos + restart
            count += 1
            if count % num_photos == 0:
                yield([[np.array(X_img), np.array(X_text)], np.array(Y)])
                
                X_img = []
                X_text = []
                Y = []
            if count >= len(photo_ids):
                if len(Y) > 0:
                    yield([[np.array(X_img), np.array(X_text)], np.array(Y)])
                break

#Training:
               
num_epoches = 20
num_photos = 32 #photos per batch
    
steps_per_epoch = int(len(train_caption_dict) / num_photos)
val_steps = int(len(dev_caption_dict) / num_photos)
    
model = define_model(max_length, vocab_size, emdedding_size, pretrained_weights)
    
train_generator = generate_dataset(train_caption_dict, train_features, max_length, vocab_size, num_photos)
dev_generator = generate_dataset(dev_caption_dict, dev_features, max_length, vocab_size, num_photos)

history = dict()
history['train_loss'] = []
history['train_acc'] = []
history['dev_loss'] = []
history['dev_acc'] = []
    
for i in range(num_epoches):
    hist = model.fit_generator(train_generator, steps_per_epoch = steps_per_epoch, epochs=5, verbose=1)
    
    history['train_loss'].append(hist.history['loss'][-1])
    history['train_acc'].append(hist.history['accuracy'][-1])
    dev_loss = model.evaluate_generator(dev_generator, steps = val_steps, verbose=1)
    history['dev_loss'].append(dev_loss[0])
    history['dev_acc'].append(dev_loss[1])
    print("The dev_loss at {i}-th epoch: {dev_loss}".format(i=i, dev_loss=np.round(dev_loss,2)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8bf206c098ad> in <module>()
#      97 num_photos = 32 #photos per batch
#      98
# ---> 99 steps_per_epoch = int(len(train_caption_dict) / num_photos)
#     100 val_steps = int(len(dev_caption_dict) / num_photos)
#     101
#
# NameError: name 'train_caption_dict' is not defined

# %%
plt.plot(history['train_acc'])
plt.plot(history['dev_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'dev'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history['train_loss'])
plt.plot(history['dev_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'dev'], loc='upper left')
plt.show()

# %%
def sample_caption(model, max_length, feature):
    """
    Input: model, photo feature: shape=[1,4096]
    Return: A generated caption of that photo feature. Remove the startseq and endseq token.
    """
    
    caption = "startseq"
    while 1:
        #Prepare input to model
        encoded = [word2idx(word) for word in caption.split()]
        padded = keras.preprocessing.sequence.pad_sequences([encoded], maxlen=max_length, padding='pre')[0]
        padded = padded.reshape((1, max_length))
        
        pred_Y = model.predict([feature, padded])[0,-1,:]
        next_word = idx2word(pred_Y.argmax())
        
        #Update caption
        caption = caption + ' ' + next_word
        
        #Terminate condition: caption length reaches maximum / reach endseq
        if next_word == 'endseq' or len(caption.split()) >= max_length:
            break
    
    #Remove the (startseq, endseq)
    caption = caption.replace('startseq ', '')
    caption = caption.replace(' endseq', '')
    
    return(caption)

def evaluate_model(model, test_caption_dict, test_features, max_length):
    """
    Print: The evaluation score based on BLEU. 
    Also, sample 3 captions using the test images.
    """
    hypo_captions_list = []
    ref_captions_list = []
    disp_captions_dict = {}
    for photo_id, caption_list in test_caption_dict.items():
        #Reference texts
        ref_captions = []
        for c in caption_list:
            ref_captions.append(c.split())
        ref_captions_list.append(ref_captions)
        
        #Sampled texts
        feature = test_features[photo_id]
        samp_caption = sample_caption(model, max_length, feature)
        hypo_captions_list.append(samp_caption.split())
        
        #save the sampled caption for each test photo
        disp_captions_dict[photo_id] = samp_caption
    
    #Evaluate the model
    bleu1 = np.round(corpus_bleu(ref_captions_list, hypo_captions_list, weights=(1, 0, 0, 0)), 2)
    bleu2 = np.round(corpus_bleu(ref_captions_list, hypo_captions_list, weights=(0.5, 0.5, 0, 0)), 2)
    bleu3 = np.round(corpus_bleu(ref_captions_list, hypo_captions_list, weights=(0.3, 0.3, 0.3, 0)), 2)
    bleu4 = np.round(corpus_bleu(ref_captions_list, hypo_captions_list, weights=(0.25, 0.25, 0.25, 0.25)), 2)
    
    print("BLEU Score on Test Set: {b1}, {b2}, {b3}, {b4}".format(b1=bleu1, b2=bleu2, b3=bleu3, b4=bleu4))
    
    #Visualize the images and captions
    photo_ids = list(test_caption_dict.keys())
    np.random.seed(1)
    samples = np.random.choice(np.arange(len(photo_ids)), 3, replace=False)
    
    for i in range(len(samples)):
        photo_id = photo_ids[samples[i]]
        
        fn = "/content/drive/My Drive/Flickr8k_Dataset/" + photo_id + '.jpg'
        img = keras.preprocessing.image.load_img(fn)
        plt.figure(i+1)
        plt.imshow(img)
        plt.figtext(0.5, 0.01, disp_captions_dict[photo_id], wrap=True, horizontalalignment='center', fontsize=12)
        

evaluate_model(model, test_caption_dict, test_features, max_length)
